# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

def plot_func(freq):
    x = np.linspace(0, 2*np.pi)
    y = np.sin(x * freq)
    plt.plot(x, y)

interact(plot_func, freq = widgets.FloatSlider(value=7.5,
                                               min=1,
                                               max=5.0,
                                               step=0.5))
# Out:
# A Jupyter Widget
# <function __main__.plot_func>

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

def plot_func(freq):
    x = np.linspace(0, 2*np.pi)
    y = np.sin(x * freq)
    plt.plot(x, y)
    plt.update()
import socket
import struct
 
#UDP_IP = "96.49.100.238"
UDP_IP = "192.168.2.103"
#UDP_IP = socket.gethostbyname(socket.gethostname())
#print "Receiver IP: ", UDP_IP
UDP_PORT = 5000
#UDP_PORT = int(raw_input ("Enter Port "))
#print "Port: ", UDP_PORT   
sock = socket.socket(socket.AF_INET, # Internet
                    socket.SOCK_DGRAM) # UDP
sock.bind((UDP_IP, UDP_PORT))


 
while True:
    data, addr = sock.recvfrom(1024) # buffer size is 1024 bytes
    #print "received message:", data    
    #print "received message: %1.3f %1.3f %1.3f %1.3f", unpack_from ('!f', data, 0), unpack_from ('!f', data, 4), unpack_from ('!f', data, 8), unpack_from ('!f', data, 12)     
#    print("received message: ", "%1.4f" %unpack_from ('!f', data, 0), 
#          "%1.4f" %unpack_from ('!f', data, 4), "%1.4f" %unpack_from ('!f', data, 8), 
#          "%1.4f" %unpack_from ('!f', data, 12),"%1.4f" %unpack_from ('!f', data, 16), 
#          "%1.4f" %unpack_from ('!f', data, 20), "%1.4f" %unpack_from ('!f', data, 24), 
#          "%1.4f" %unpack_from ('!f', data, 28),"%1.4f" %unpack_from ('!f', data, 32), 
#          "%1.4f" %unpack_from ('!f', data, 36), "%1.4f" %unpack_from ('!f', data, 40), 
#          "%1.4f" %unpack_from ('!f', data, 44), "%1.4f" %unpack_from ('!f', data, 48), 
#          "%1.4f" %unpack_from ('!f', data, 52), "%1.4f" %unpack_from ('!f', data, 56), 
#          "%1.4f" %unpack_from ('!f', data, 60), "%1.4f" %unpack_from ('!f', data, 64), 
#          "%1.4f" %unpack_from ('!f', data, 68), "%1.4f" %unpack_from ('!f', data, 72), 
#          "%1.4f" %unpack_from ('!f', data, 76), "%1.4f" %unpack_from ('!f', data, 80), 
#          "%1.4f" %unpack_from ('!f', data, 84), "%1.4f" %unpack_from ('!f', data, 88), 
#          "%1.4f" %unpack_from ('!f', data, 92))
    
    #print("%1.4f" %struct.unpack_from ('!f', data, 6*4))
    
    x = struct.unpack_from ('!f', data, 6*4)
    plot_func(x)

# %%
import time
import numpy as np
# ------------------- new cell ---------------------#

from bokeh.models.sources import ColumnDataSource
from bokeh.plotting import figure
from bokeh.io import output_notebook, show, push_notebook
# ------------------- new cell ---------------------#

output_notebook()
# ------------------- new cell ---------------------#

import sys
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="54566b37-b425-43bf-b7dd-237eb790f1ae">Loading BokehJS ...</span>
#     </div>

# %%
my_figure = figure(plot_width=800, plot_height=400)
test_data = ColumnDataSource(data=dict(x=[0], y=[0]))
line = my_figure.line("x", "y", source=test_data)
handle = show(my_figure, notebook_handle=True)

UDP_IP = "192.168.2.103"
#UDP_IP = socket.gethostbyname(socket.gethostname())
#print "Receiver IP: ", UDP_IP
UDP_PORT = 5000
sock = socket.socket(socket.AF_INET, # Internet
                    socket.SOCK_DGRAM) # UDP
sock.bind((UDP_IP, UDP_PORT))

new_data=dict(x=[0], y=[0])
x = []
y = []

step = 0
step_size = 0.1  # increment for increasing step
max_step = 1  # arbitrary stop point for example
period = .001  # in seconds (simulate waiting for new data)
n_show = 100  # number of points to keep and show
while True:
    data, addr = sock.recvfrom(64) # buffer size is 1024 bytes
    #x_ = struct.unpack_from ('!f', data, 3*4)[0]
    x_ = float(str(data).split(',')[3])
    #x.append(step)
    #y.append(x_)
    #print(data)
    #new_data['x'] = x = x[-n_show:]  # prevent filling ram
    #new_data['y'] = y = y[-n_show:]  # prevent filling ram

    #test_data.stream(new_data, n_show)
    
    #push_notebook(handle=handle)
    #step += step_size
   # time.sleep(period)
    sys.stdout.write("\r" + str(x_))
    sys.stdout.flush()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6e4f5179-1cfa-49fb-90f3-ebe290006d38"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6e4f5179-1cfa-49fb-90f3-ebe290006d38");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6e4f5179-1cfa-49fb-90f3-ebe290006d38");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6e4f5179-1cfa-49fb-90f3-ebe290006d38' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c569d0bc-31b6-419a-adce-896c1dbefad5":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"50e44f60-1e7a-4891-8d18-4d2757a34a9e","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2f25a778-aebe-4705-9bea-029552bccfc5","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"2bcc403a-b82d-4325-b006-7a8521d23781","type":"ColumnDataSource"},"glyph":{"id":"50e44f60-1e7a-4891-8d18-4d2757a34a9e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0f4a6813-ae49-45db-bb3c-7483bae91e23","type":"Line"},"selection_glyph":null,"view":{"id":"992e7321-3636-4c6f-89d5-02961af0c526","type":"CDSView"}},"id":"f974e2aa-a9a1-4723-8abc-63025fc490d6","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"698aaa56-5af4-4ac9-bcef-63160c22cfbf","type":"BasicTickFormatter"},"plot":{"id":"297002e8-5634-435a-9425-374f19ff99c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad5b9a5f-5e17-4145-aaca-45774171cdf4","type":"BasicTicker"}},"id":"fcd123ed-7a7e-420d-8109-36234c269686","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0f4a6813-ae49-45db-bb3c-7483bae91e23","type":"Line"},{"attributes":{},"id":"757ab080-7a0d-45e3-a5a5-ca71d6de8841","type":"LinearScale"},{"attributes":{},"id":"76209714-72c0-40fd-82f9-fd5d398f95fe","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"2f25a778-aebe-4705-9bea-029552bccfc5","type":"BoxAnnotation"}},"id":"b7a99264-8660-47d5-8ef8-819804abe4e2","type":"BoxZoomTool"},{"attributes":{"source":{"id":"2bcc403a-b82d-4325-b006-7a8521d23781","type":"ColumnDataSource"}},"id":"992e7321-3636-4c6f-89d5-02961af0c526","type":"CDSView"},{"attributes":{},"id":"d89d3ec0-3c0f-4585-a0b1-a0d63bd939ba","type":"BasicTicker"},{"attributes":{"callback":null},"id":"feaee7ae-ee8c-428a-a317-2d96a9e86299","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"297002e8-5634-435a-9425-374f19ff99c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"d89d3ec0-3c0f-4585-a0b1-a0d63bd939ba","type":"BasicTicker"}},"id":"853a0fe3-ecef-4fea-8e72-0cd837c3c567","type":"Grid"},{"attributes":{"below":[{"id":"fcd123ed-7a7e-420d-8109-36234c269686","type":"LinearAxis"}],"left":[{"id":"885c58b5-29eb-47dc-9d54-ce20a61c23e5","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"fcd123ed-7a7e-420d-8109-36234c269686","type":"LinearAxis"},{"id":"5871fa14-6acc-480e-8f11-121dbfd712bb","type":"Grid"},{"id":"885c58b5-29eb-47dc-9d54-ce20a61c23e5","type":"LinearAxis"},{"id":"853a0fe3-ecef-4fea-8e72-0cd837c3c567","type":"Grid"},{"id":"2f25a778-aebe-4705-9bea-029552bccfc5","type":"BoxAnnotation"},{"id":"f974e2aa-a9a1-4723-8abc-63025fc490d6","type":"GlyphRenderer"}],"title":{"id":"1ef73e91-2164-46d6-956a-cd0fb9cf0a92","type":"Title"},"toolbar":{"id":"9e6db05f-faf0-4b51-b97a-a1110e35114a","type":"Toolbar"},"x_range":{"id":"17cd47a9-a72e-4875-be14-0aa4e9d2115c","type":"DataRange1d"},"x_scale":{"id":"757ab080-7a0d-45e3-a5a5-ca71d6de8841","type":"LinearScale"},"y_range":{"id":"feaee7ae-ee8c-428a-a317-2d96a9e86299","type":"DataRange1d"},"y_scale":{"id":"ebb790db-2724-4f60-ade4-a949006c4362","type":"LinearScale"}},"id":"297002e8-5634-435a-9425-374f19ff99c9","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"297002e8-5634-435a-9425-374f19ff99c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad5b9a5f-5e17-4145-aaca-45774171cdf4","type":"BasicTicker"}},"id":"5871fa14-6acc-480e-8f11-121dbfd712bb","type":"Grid"},{"attributes":{},"id":"4c50b0ae-3429-4628-8c09-c26d60ea0bb2","type":"PanTool"},{"attributes":{"formatter":{"id":"1b8ee244-4a18-4822-9a66 ...
# 341.6385498

# %%
float(str(data).split(',')[3])
# Out:
# 287.1494141

# %%
    #print "received message:", data    
    #print "received message: %1.3f %1.3f %1.3f %1.3f", unpack_from ('!f', data, 0), unpack_from ('!f', data, 4), unpack_from ('!f', data, 8), unpack_from ('!f', data, 12)     
#    print("received message: ", "%1.4f" %unpack_from ('!f', data, 0), 
#          "%1.4f" %unpack_from ('!f', data, 4), "%1.4f" %unpack_from ('!f', data, 8), 
#          "%1.4f" %unpack_from ('!f', data, 12),"%1.4f" %unpack_from ('!f', data, 16), 
#          "%1.4f" %unpack_from ('!f', data, 20), "%1.4f" %unpack_from ('!f', data, 24), 
#          "%1.4f" %unpack_from ('!f', data, 28),"%1.4f" %unpack_from ('!f', data, 32), 
#          "%1.4f" %unpack_from ('!f', data, 36), "%1.4f" %unpack_from ('!f', data, 40), 
#          "%1.4f" %unpack_from ('!f', data, 44), "%1.4f" %unpack_from ('!f', data, 48), 
#          "%1.4f" %unpack_from ('!f', data, 52), "%1.4f" %unpack_from ('!f', data, 56), 
#          "%1.4f" %unpack_from ('!f', data, 60), "%1.4f" %unpack_from ('!f', data, 64), 
#          "%1.4f" %unpack_from ('!f', data, 68), "%1.4f" %unpack_from ('!f', data, 72), 
#          "%1.4f" %unpack_from ('!f', data, 76), "%1.4f" %unpack_from ('!f', data, 80), 
#          "%1.4f" %unpack_from ('!f', data, 84), "%1.4f" %unpack_from ('!f', data, 88), 
#          "%1.4f" %unpack_from ('!f', data, 92))
    
    #print("%1.4f" %struct.unpack_from ('!f', data, 6*4))
    
    
    plot_func(x)
