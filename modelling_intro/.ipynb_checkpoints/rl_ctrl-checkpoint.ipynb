# %%
import numba 
from numba import float64
import numpy as np
import matplotlib.pyplot as plt
from numba import jit
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c99c66b3-8197-423a-9895-02184f3c85c1">Loading BokehJS ...</span>
#     </div>

# %%
@numba.jit(nopython=True)
def f_rl_eval(t,u,x,y,param):
    f =  np.zeros((1,1))
    
    i_l = x[0]
    
    L = param[0]
    R = param[1]

    v = u[0]

    di_l = 1.0/L*(v - R*i_l)
    
    f[0] = di_l

    return f

@numba.jit(nopython=True)
def h_rl_eval(t,u,x,y,param):
    h =  np.zeros((1,1))
    i_l = x[0]

    h[0,0] = i_l

    return h

@numba.jit(nopython=True)
def run():
    dt = 5e-6
    t_end = 0.1  
    decimation = 1
    N_steps = int(t_end/dt)
    N_saves = int(t_end/dt/decimation)
    T = np.zeros((N_saves,1))
    X = np.zeros((N_saves,1))
    
    t = 0.0
    x_0 = np.zeros((1,1))
    x = x_0

    X[0,:] = x
    
    param = np.array([0.001, # L
                      1.0   # R
                     ])


    u = np.zeros((1,1))

    it = 0
    it_decimation = 0
    it_save = 0
    solver = 1
    for it in range(N_steps):   
        if t > 0.01:
            u[0] = 10.0
            
        t += dt        

        if solver == 1:
            # solver trapezoidal 1 step
            x = x + dt*(f_rl_eval(t,u,x,0.0,param))
        
        if solver == 2:
            # solver trapezoidal 1 step
            f_1 = f_rl_eval(t,u,x,0.0,param)
            x_1 = x + dt*f_1
            x = x + 0.5*dt*(f_rl_eval(t,u,x,0.0,param)+ f_1)

        
        
        if it_decimation >= decimation:
            it_save += 1  
            X[it_save,:] = x
            T[it_save,:] = t
            it_decimation = 0
            
        it_decimation += 1              
        
        
    return T,X


#%timeit run()

T,X = run()

# %%
fig1 = figure(width=800, height=300)
fig1.line(x=T[:,0], y=X[:,0], color="red")
 


figs = gridplot([[fig1]])

show(figs)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c0f65a16-dc5e-457a-a481-22983696b44c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c0f65a16-dc5e-457a-a481-22983696b44c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0f65a16-dc5e-457a-a481-22983696b44c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0f65a16-dc5e-457a-a481-22983696b44c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"98407140-3799-48fd-905d-93368c3e5a37":{"roots":{"references":[{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"db55d035-6bbb-4567-ade4-74a89ec1cede","type":"PanTool"},{"id":"fcfbebba-7599-4423-b4be-4028d477ed11","type":"WheelZoomTool"},{"id":"fc0a6d67-537c-4ca7-a965-7604cc3f08d6","type":"BoxZoomTool"},{"id":"22cbcc2d-d9cb-4ffd-9e1e-0e88e46c2f69","type":"SaveTool"},{"id":"8721a74b-9aaf-492c-b46e-93b81b434de1","type":"ResetTool"},{"id":"f0f023da-785e-4e05-ba0f-b5702ae9cb7c","type":"HelpTool"}]},"id":"79ec9a5e-952d-4f57-bb35-185e0e5e7579","type":"ToolbarBox"},{"attributes":{},"id":"8ddd002a-eab6-4de8-8f1b-b30bc4ce4619","type":"BasicTickFormatter"},{"attributes":{},"id":"ec09d03c-ebaa-4ea5-82ba-a516e8221b76","type":"ToolEvents"},{"attributes":{"plot":null,"text":null},"id":"6ad62966-165d-47f9-8b2c-3f400106bef6","type":"Title"},{"attributes":{"children":[{"id":"4abd6111-29c2-4306-9922-515bb6c63cab","type":"Row"}]},"id":"8970c6e8-5a59-41d4-bae8-e01d35d18252","type":"Column"},{"attributes":{"formatter":{"id":"b2954c35-8248-44cd-bce1-3f65bfb5593a","type":"BasicTickFormatter"},"plot":{"id":"0caf65ae-720e-4763-8185-778e54c3873c","subtype":"Figure","type":"Plot"},"ticker":{"id":"11511020-d0c1-4fc5-a07c-2b84f4ba4843","type":"BasicTicker"}},"id":"51b26b3d-a994-4760-b34d-af60f04aa45e","type":"LinearAxis"},{"attributes":{},"id":"2e8e0e8c-1e4e-4962-a728-5b91adc24858","type":"BasicTicker"},{"attributes":{},"id":"11511020-d0c1-4fc5-a07c-2b84f4ba4843","type":"BasicTicker"},{"attributes":{"callback":null},"id":"39acb1d2-7b65-4b29-81f7-e2561e508773","type":"DataRange1d"},{"attributes":{"callback":null},"id":"ae8f2f36-5dd0-41df-9cf8-75cb94bbd639","type":"DataRange1d"},{"attributes":{"plot":{"id":"0caf65ae-720e-4763-8185-778e54c3873c","subtype":"Figure","type":"Plot"}},"id":"22cbcc2d-d9cb-4ffd-9e1e-0e88e46c2f69","type":"SaveTool"},{"attributes":{"data_source":{"id":"9ff60866-89c2-4a6d-8efb-65924dfe8533","type":"ColumnDataSource"},"glyph":{"id":"60b56f09-a1f4-4868-990d-59c06c765bbb","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"50684d7e-b55b-4327-b5cf-2c2f1cbeb5eb","type":"Line"},"selection_glyph":null},"id":"620b0095-d42f-47cd-908c-2050a495a5d6","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"0caf65ae-720e-4763-8185-778e54c3873c","subtype":"Figure","type":"Plot"}]},"id":"4abd6111-29c2-4306-9922-515bb6c63cab","type":"Row"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b907aa2e-275a-43f0-b479-34e05b625d69","type":"BoxAnnotation"},{"attributes":{"children":[{"id":"79ec9a5e-952d-4f57-bb35-185e0e5e7579","type":"ToolbarBox"},{"id":"8970c6e8-5a59-41d4-bae8-e01d35d18252","type":"Column"}]},"id":"c33a4056-c2bd-4ac0-b2a0-f2587e950cf3","type":"Column"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"50684d7e-b55b-4327-b5cf-2c2f1cbeb5eb","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"0caf65ae-720e-4763-8185-778e54c3873c","subtype":"Figure","type":"Plot"},"ticker":{"id":"11511020-d0c1-4fc5-a07c-2b84f4ba4843","type":"BasicTicker"}},"id":"225aecf2-1cf1-46e2-b0ab-0f20ff78df96","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,1e-05,1.5000000000000002e-05,2e-05,2.5e-05,3e-05,3.5000000000000004e-05,4e-05,4.5e-05,5e-05,5.5e-05,6e-05,6.500000000000001e-05,7.000000000000001e-05,7.500000000000001e-05,8e-05,8.5e-05,9e-05,9.5e-05,0.0001,0.000105,0.00011,0.000115,0.00012,0.000125,0.00013000000000000002,0.00013500000000000003,0.00014000000000000004,0.00014500000000000006,0.00015000000000000007,0.00015500000000000008,0.0001600000000000001,0.0001650000000000001,0.00017000000000000012,0.000175000 ...

# %%
#@numba.jit(float64[:](float64,float64,float64[:],float64,float64[:]))
@numba.jit(nopython=True)
def f_pi_eval(t,u,x,y,param):
    f =  np.zeros((1,1))
    xi = x[0]
    
    K_p = param[0]
    T_pi = param[1]

    ref = u[0]
    y   = u[1]

    error = ref - y
    dxi = error
    
    f[0] = dxi

    return f

@numba.jit(nopython=True)
def h_pi_eval(t,u,x,y,param):
    h =  np.zeros((1,1))
    
    xi = x[0]
    
    K_p = param[0]
    T_pi = param[1]

    ref = u[0]
    y   = u[1]

    error = ref - y
    
    h[0] = K_p*(error + 1.0/T_pi*xi)
    
    return h

@numba.jit(nopython=True)
def f_eval(t,u,x,y,param):
    
    f = np.zeros((2,1))
    u_pi= np.zeros((2,1))
    u_rl= np.zeros((2,1))
    
    ref = u[0]
    
    i_l = h_rl_eval(t,u,x[0,:],y,param)
    
    u_pi[0] = ref
    u_pi[1] = i_l
   
    pi_out = h_pi_eval(t,u_pi,x[1,:],y,param[2:4])
    
    
    u_rl[0] = pi_out
    
    f[0] = f_rl_eval(t,u_rl,x[0,:],y,param[0:2])
    f[1] = f_pi_eval(t,u_pi,x[1,:],y,param[2:4])
    
    return f
    
    
    
@numba.jit(nopython=True)
def run():
    dt = 5e-6
    t_end = 0.1  
    decimation = 10
    N_steps = int(t_end/dt)
    N_saves = int(t_end/dt/decimation)
    T = np.zeros((N_saves,1))
    X = np.zeros((N_saves,2))
    
    t = 0.0
    x_0 = np.zeros((2,1))
    x = x_0

    X[0,:] = x[:,0]
    
    param = np.array([0.001, # L
                      1.0,   # R
                      0.001/0.0001, # K_p
                      0.001   # T_pi
                     ])    

    u = np.zeros((2,1))

    it = 0
    it_decimation = 0
    it_save = 0
    solver = 1
    for it in range(N_steps):   
        if t > 0.01:
            u[0] = 10.0
            
        t += dt        

        if solver == 1:
            # solver trapezoidal 1 step
            x = x + dt*(f_eval(t,u,x,0.0,param))
        
        if solver == 2:
            # solver trapezoidal 1 step
            f_1 = f_eval(t,u,x,0.0,param)
            x_1 = x + dt*f_1
            x = x + 0.5*dt*(f_eval(t,u,x,0.0,param)+ f_1)

        
        
        if it_decimation >= decimation:
            it_save += 1  
            X[it_save,:] = x[:,0]
            T[it_save,:] = t
            it_decimation = 0
            
        it_decimation += 1              
        
        
    return T,X
   
# %timeit run()

T,X = run()
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-21-d9fea12dfc7a> in <module>()
#     119     return T,X
#     120
# --> 121 get_ipython().magic('timeit run()')
#     122
#     123 T,X = run()
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-58> in timeit(self, line, cell)
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell)
#    1042             number = 1
#    1043             for _ in range(1, 10):
# -> 1044                 time_number = timer.timeit(number)
#    1045                 worst_tuning = max(worst_tuning, time_number / number)
#    1046                 if time_number >= 0.2:
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     137         gc.disable()
#     138         try:
# --> 139             timing = self.inner(it, self.timer)
#     140         finally:
#     141             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/dispatcher.py in _compile_for_args(self, *args, **kws)
#     308                                 for i, err in failed_args))
#     309                 e.patch_message(msg)
# --> 310             raise e
#     311
#     312     def inspect_llvm(self, signature=None):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/dispatcher.py in _compile_for_args(self, *args, **kws)
#     285                 argtypes.append(self.typeof_pyval(a))
#     286         try:
# --> 287             return self.compile(tuple(argtypes))
#     288         except errors.TypingError as e:
#     289             # Intercept typing error that may be due to an argument
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/dispatcher.py in compile(self, sig)
#     553
#     554             self._cache_misses[sig] += 1
# --> 555             cres = self._compiler.compile(args, return_type)
#     556             self.add_overload(cres)
#     557             self._cache.save_overload(sig, cres)
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/dispatcher.py in compile(self, args, return_type)
#      79                                       impl,
#      80                                       args=args, return_type=return_type,
# ---> 81                                       flags=flags, locals=self.locals)
#      82         # Check typing error if object mode is used
#      83         if cres.typing_error is not None and not flags.enable_pyobject:
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library)
#     697     pipeline = Pipeline(typingctx, targetctx, library,
#     698                         args, return_type, flags, locals)
# --> 699     return pipeline.compile_extra(func)
#     700
#     701
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in compile_extra(self, func)
#     350         self.lifted = ()
#     351         self.lifted_from = None
# --> 352         return self._compile_bytecode()
#     353
#     354     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in _compile_bytecode(self)
#     658         """
#     659         assert self.func_ir is None
# --> 660         return self._compile_core()
#     661
#     662     def _compile_ir(self):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in _compile_core(self)
#     645
#     646         pm.finalize()
# --> 647         res = pm.run(self.status)
#     648         if res is not None:
#     649             # Early pipeline completion
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in run(self, status)
#     236                     # No more fallback pipelines?
#     237                     if is_final_pipeline:
# --> 238                         raise patched_exception
#     239                     # Go to next fallback pipeline
#     240                     else:
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in run(self, status)
#     228                 try:
#     229                     event(stage_name)
# --> 230                     stage()
#     231                 except _EarlyPipelineCompletion as e:
#     232                     return e.result
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in stage_nopython_frontend(self)
#     442                 self.args,
#     443                 self.return_type,
# --> 444                 self.locals)
#     445
#     446         with self.fallback_context('Function "%s" has invalid return type'
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in type_inference_stage(typingctx, interp, args, return_type, locals)
#     798
#     799         infer.build_constraint()
# --> 800         infer.propagate()
#     801         typemap, restype, calltypes = infer.unify()
#     802
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in propagate(self, raise_errors)
#     765         if errors:
#     766             if raise_errors:
# --> 767                 raise errors[0]
#     768             else:
#     769                 return errors
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in propagate(self, typeinfer)
#     126                                                    lineno=loc.line):
#     127                 try:
# --> 128                     constraint(typeinfer)
#     129                 except TypingError as e:
#     130                     errors.append(e)
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in __call__(self, typeinfer)
#     377             fnty = typevars[self.func].getone()
#     378             with new_error_context("resolving callee type: {0}", fnty):
# --> 379                 self.resolve(typeinfer, typevars, fnty)
#     380
#     381     def resolve(self, typeinfer, typevars, fnty):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in resolve(self, typeinfer, typevars, fnty)
#     390
#     391         # Resolve call type
# --> 392         sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     393         if sig is None:
#     394             # Arguments are invalid => explain why
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in resolve_call(self, fnty, pos_args, kw_args)
#    1028         else:
#    1029             # Normal non-recursive call
# -> 1030             return self.context.resolve_function_type(fnty, pos_args, kw_args)
#    1031
#    1032     def typeof_global(self, inst, target, gvar):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typing/context.py in resolve_function_type(self, func, args, kws)
#     200         if isinstance(func, types.Callable):
#     201             # XXX fold this into the __call__ attribute logic?
# --> 202             return func.get_call_type(self, args, kws)
#     203
#     204     def _get_attribute_templates(self, typ):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/types/functions.py in get_call_type(self, context, args, kws)
#     157         is available for it.
#     158         """
# --> 159         template, pysig, args, kws = self.dispatcher.get_call_template(args, kws)
#     160         sig = template(context).apply(args, kws)
#     161         if sig:
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/dispatcher.py in get_call_template(self, args, kws)
#     247         # Ensure an overload is available
#     248         if self._can_compile:
# --> 249             self.compile(tuple(args))
#     250
#     251         # Create function type for typing
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/dispatcher.py in compile(self, sig)
#     553
#     554             self._cache_misses[sig] += 1
# --> 555             cres = self._compiler.compile(args, return_type)
#     556             self.add_overload(cres)
#     557             self._cache.save_overload(sig, cres)
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/dispatcher.py in compile(self, args, return_type)
#      79                                       impl,
#      80                                       args=args, return_type=return_type,
# ---> 81                                       flags=flags, locals=self.locals)
#      82         # Check typing error if object mode is used
#      83         if cres.typing_error is not None and not flags.enable_pyobject:
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library)
#     697     pipeline = Pipeline(typingctx, targetctx, library,
#     698                         args, return_type, flags, locals)
# --> 699     return pipeline.compile_extra(func)
#     700
#     701
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in compile_extra(self, func)
#     350         self.lifted = ()
#     351         self.lifted_from = None
# --> 352         return self._compile_bytecode()
#     353
#     354     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in _compile_bytecode(self)
#     658         """
#     659         assert self.func_ir is None
# --> 660         return self._compile_core()
#     661
#     662     def _compile_ir(self):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in _compile_core(self)
#     645
#     646         pm.finalize()
# --> 647         res = pm.run(self.status)
#     648         if res is not None:
#     649             # Early pipeline completion
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in run(self, status)
#     236                     # No more fallback pipelines?
#     237                     if is_final_pipeline:
# --> 238                         raise patched_exception
#     239                     # Go to next fallback pipeline
#     240                     else:
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in run(self, status)
#     228                 try:
#     229                     event(stage_name)
# --> 230                     stage()
#     231                 except _EarlyPipelineCompletion as e:
#     232                     return e.result
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in stage_nopython_frontend(self)
#     442                 self.args,
#     443                 self.return_type,
# --> 444                 self.locals)
#     445
#     446         with self.fallback_context('Function "%s" has invalid return type'
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/compiler.py in type_inference_stage(typingctx, interp, args, return_type, locals)
#     797             infer.seed_type(k, v)
#     798
# --> 799         infer.build_constraint()
#     800         infer.propagate()
#     801         typemap, restype, calltypes = infer.unify()
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in build_constraint(self)
#     721         for blk in utils.itervalues(self.blocks):
#     722             for inst in blk.body:
# --> 723                 self.constrain_statement(inst)
#     724
#     725     def return_types_from_partial(self):
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in constrain_statement(self, inst)
#     880     def constrain_statement(self, inst):
#     881         if isinstance(inst, ir.Assign):
# --> 882             self.typeof_assign(inst)
#     883         elif isinstance(inst, ir.SetItem):
#     884             self.typeof_setitem(inst)
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in typeof_assign(self, inst)
#     938                                               src=value.name, loc=inst.loc))
#     939         elif isinstance(value, (ir.Global, ir.FreeVar)):
# --> 940             self.typeof_global(inst, inst.target, value)
#     941         elif isinstance(value, ir.Arg):
#     942             self.typeof_arg(inst, inst.target, value)
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in typeof_global(self, inst, target, gvar)
#    1032     def typeof_global(self, inst, target, gvar):
#    1033         try:
# -> 1034             typ = self.resolve_value_type(inst, gvar.value)
#    1035         except TypingError as e:
#    1036             if (gvar.name == self.func_id.func_name
#
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numba/typeinfer.py in resolve_value_type(self, inst, val)
#     957         except ValueError as e:
#     958             msg = str(e)
# --> 959         raise TypingError(msg, loc=inst.loc)
#     960
#     961     def typeof_arg(self, inst, target, arg):
#
# TypingError: Failed at nopython (nopython frontend)
# Failed at nopython (nopython frontend)
# Untyped global name 'h_rl_eval': cannot determine Numba type of <class 'object'>
# File "<ipython-input-21-d9fea12dfc7a>", line 47
# [1] During: resolving callee type: type(CPUDispatcher(<function f_eval at 0x7f04b3dbad90>))
# [2] During: typing of call at <ipython-input-21-d9fea12dfc7a> (100)

# %%
fig1 = figure(width=800, height=300)
fig1.line(x=T[:,0], y=X[:,0], color="red")
 


figs = gridplot([[fig1]])

show(figs)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="4f9f36f2-ff12-480d-b455-d2ef52ef5292"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#4f9f36f2-ff12-480d-b455-d2ef52ef5292").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4f9f36f2-ff12-480d-b455-d2ef52ef5292");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4f9f36f2-ff12-480d-b455-d2ef52ef5292' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e3b4d038-8a68-473f-8366-37cdbc43ffc8":{"roots":{"references":[{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"96fc7d28-baa5-414c-863c-1e1736edf420","type":"PanTool"},{"id":"7e4b3bd8-bacb-4085-a221-9219f6ea8cb7","type":"WheelZoomTool"},{"id":"1b9b958e-9d82-4fc1-ad88-90557d8cc420","type":"BoxZoomTool"},{"id":"3d5eca44-c6c2-455a-a495-36ff203268d1","type":"SaveTool"},{"id":"7c69ae8f-60d0-42e6-a2a3-f82900833377","type":"ResetTool"},{"id":"5a4d9aff-c8ef-4653-bcfd-5194631aa9ee","type":"HelpTool"}]},"id":"918fcf57-dd34-4b06-a3a4-dccdee972a38","type":"ToolbarBox"},{"attributes":{"plot":{"id":"8122a9dd-0b53-4c30-91ea-0d1da0facfc2","subtype":"Figure","type":"Plot"}},"id":"7e4b3bd8-bacb-4085-a221-9219f6ea8cb7","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"
    
    
    u_rl[0] = pi_out
    
    f[0] = rl.f_eval(t,u_rl,x[0,:],y)
    f[1] = pi.f_eval(t,u_pi,x[1,:],y)
    
    return f

   
    
@numba.jit(nopython=True)
def run():
    dt = 10e-6
    t_end = 1.0  
    decimation = 1000
    N_steps = int(t_end/dt)
    N_saves = int(t_end/dt/decimation)
    T = np.zeros((N_saves,1))
    X = np.zeros((N_saves,2))
    
    t = 0.0
    x_0 = np.zeros((2,1))
    x = x_0

    X[0,:] = x[:,0]
    
    param = np.array([0.001, # L
                      1.0,   # R
                      0.001/0.0001, # K_p
                      0.001   # T_pi
                     ])    

    u = np.zeros((1,1))

    it = 0
    it_decimation = 0
    it_save = 0
    solver = 2

    
    
    f = np.zeros((2,1))
    
    pi = ctrl.pi()
    rl = electric.rl()
    
    pi.K_p = 100.0
    pi.T_pi = 1.0
    u_pi= np.zeros((2,1))
    u_rl= np.zeros((2,1))

    y = np.zeros(())
    
    for it in range(N_steps):   
        if t > 0.01:
            u[0] = 10.0
            
        t += dt        

        if solver == 1:
            # solver trapezoidal 1 step
            ref = u[0]

            i_l = rl.h_eval(t,u,x[0,:],y)

            u_pi[0] = ref
            u_pi[1] = i_l

            pi_out = pi.h_eval(t,u_pi,x[1,:],y)


            u_rl[0] = pi_out

            f[0] = rl.f_eval(t,u_rl,x[0,:],y)
            f[1] = pi.f_eval(t,u_pi,x[1,:],y)
    
    
            
            
            x = x + dt*(f)

        if solver == 11:
            # solver trapezoidal 1 step
            x = x + dt*(f_eval(t,u,x,y,rl,pi))
            
        if solver == 2:
            # solver trapezoidal 1 step
            f_1 = f_eval(t,u,x,y,rl,pi)
            x_1 = x + dt*f_1
            x = x + 0.5*dt*(f_eval(t,u,x_1,y,rl,pi)+ f_1)

        
        
        if it_decimation >= decimation:
            it_save += 1  
            X[it_save,:] = x[:,0]
            T[it_save,:] = t
            it_decimation = 0
            
        it_decimation += 1              
        
        
    return T,X
   
# %timeit run()

T,X = run()
# Out:
# The slowest run took 6.09 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1 loop, best of 3: 247 ms per loop

# %%
fig1 = figure(width=800, height=300)
fig1.line(x=T[:,0], y=X[:,0], color="red")
 


figs = gridplot([[fig1]])

show(figs)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c892d84f-c665-4ec8-b422-0b5320b74c9b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c892d84f-c665-4ec8-b422-0b5320b74c9b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c892d84f-c665-4ec8-b422-0b5320b74c9b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c892d84f-c665-4ec8-b422-0b5320b74c9b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a9056fdb-9b86-4114-9205-368fac236195":{"roots":{"references":[{"attributes":{"formatter":{"id":"36957d8d-7e81-458e-874d-c74db33da7ac","type":"BasicTickFormatter"},"plot":{"id":"b3fb170e-b86e-4c4d-b926-999bd8c4282c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e89afea6-0ce7-47f7-a353-f599191be85b","type":"BasicTicker"}},"id":"ab53af7e-0ab8-4f4a-9107-51aec4e15af7","type":"LinearAxis"},{"attributes":{"plot":null,"text":null},"id":"aa3c5c87-920f-4e3a-80f2-996a7455ba65","type":"Title"},{"attributes":{},"id":"6c5ba9d8-fc47-47b3-a83e-d9f3bf7c96a1","type":"ToolEvents"},{"attributes":{},"id":"23dacbe2-c09d-490e-86c9-0e84d3c1c361","type":"BasicTicker"},{"attributes":{"plot":{"id":"b3fb170e-b86e-4c4d-b926-999bd8c4282c","subtype":"Figure","type":"Plot"}},"id":"df2898d0-ac1f-4358-a7ec-814e4b1aa063","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"