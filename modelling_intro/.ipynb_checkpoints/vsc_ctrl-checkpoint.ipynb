# %%
import numba 
from numba import float64
import numpy as np
import matplotlib.pyplot as plt
from numba import jit
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5834c142-1573-4ee9-acad-b7a0d508b5a0">Loading BokehJS ...</span>
#     </div>

# %%
import ctrl
import electric

vsc = electric.vsc()
vsrc = electric.source3ph()

# %%
import ctrl
import electric
 
    
@numba.jit(nopython=True)
def run():
    dt = 50e-6
    t_end = 0.2
    decimation = 1
    N_steps = int(t_end/dt)
    N_saves = int(t_end/dt/decimation)
    T = np.zeros((N_saves,1))
    X = np.zeros((N_saves,3))
    Y = np.zeros((N_saves,7))
    Y1 = np.zeros((N_saves,3))
    
    vsc = electric.vsc()
    vsrc = electric.source3ph()
    
    t = 0.0
    x_0 = vsc.x_0
    x = x_0
    y = np.zeros(())

    u_vsc= np.zeros((7,1))
    X[0,:] = x[:,0]
    Y[0,:] = vsc.h_eval(t,u_vsc,x,y)[:,0]

    it = 0
    it_decimation = 0
    it_save = 0
    solver = 1
    
    f = np.zeros((2,1))    
    vsc.C = 2200e10
    u_vsc[6] = 0.0
    
    for it in range(N_steps):   
        if t > 0.1:
            u_vsc[6] = 0.0
            
        t += dt        

        if solver == 1:
            # solver trapezoidal 1 step

            u_vsc[0:3] = vsrc.h_eval(t)/400.0*0.9
            u_vsc[3:6] = vsrc.h_eval(t)

            f = vsc.f_eval(t,u_vsc,x,y) 

            x = x + dt*(f)

        if it_decimation >= decimation:
            it_save += 1  
            X[it_save,:] = x[:,0]
            Y[it_save,:] = vsc.h_eval(t,u_vsc,x,y)[:,0]
            Y1[it_save,:] = u_vsc[0:3,0]
            T[it_save,:] = t
            it_decimation = 0
            
        it_decimation += 1              
        
        
    return T,X,Y,Y1
   
# %timeit run()

T,X,Y,Y1 = run()
# Out:
# The slowest run took 33.33 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1 loop, best of 3: 27.1 ms per loop

# %%
fig1 = figure(width=800, height=300)
fig1.line(x=T[:,0], y=Y[:,0], color="red")
fig1.line(x=T[:,0], y=Y[:,1], color="green")
fig1.line(x=T[:,0], y=Y[:,2], color="blue")

fig2 = figure(width=800, height=300)
fig2.line(x=T[:,0], y=Y[:,3], color="red")

fig3 = figure(width=800, height=300)
fig3.line(x=T[:,0], y=Y[:,4], color="red")
fig3.line(x=T[:,0], y=Y[:,5], color="green")
fig3.line(x=T[:,0], y=Y[:,6], color="blue")

figs = gridplot([[fig1],[fig2],[fig3]])

show(figs)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="bc63195e-880b-4c40-9a65-244b7c012a9c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#bc63195e-880b-4c40-9a65-244b7c012a9c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bc63195e-880b-4c40-9a65-244b7c012a9c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bc63195e-880b-4c40-9a65-244b7c012a9c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5af70348-d5ea-4158-b1df-7cc7c37fb1d4":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0c4660f8-920a-469e-bb1e-520d61ca26e7","type":"Line"},{"attributes":{"plot":null,"text":null},"id":"729084ea-4bea-48a6-9de9-29514510d7c6","type":"Title"},{"attributes":{"callback":null},"id":"38bf7dfc-79fe-4540-932b-53ad4ba2c35f","type":"DataRange1d"},{"attributes":{"formatter":{"id":"3bf50973-24ab-43a0-9a14-53b5d244ca5c","type":"BasicTickFormatter"},"plot":{"id":"9103d3b5-aba2-4377-97da-bce471708ec0","subtype":"Figure","type":"Plot"},"ticker":{"id":"f401ff87-660c-40e4-9497-3269ddff4603","type":"BasicTicker"}},"id":"7b873c90-ca13-49c7-8343-754d1ed48c59","type":"LinearAxis"},{"attributes":{"below":[{"id":"6fbf281b-e3d1-4e4d-a4fb-fcc2785617e5","type":"LinearAxis"}],"left":[{"id":"1cac6395-9b27-47d5-be3c-95c8422fbb41","type":"LinearAxis"}],"plot_height":300,"plot_width":800,"renderers":[{"id":
001081081081081081,0.0011011011011011012,0.001121121121121121,0.0011411411411411411,0.0011611611611611612,0.001181181181181181,0.0012012012012012011,0.0012212212212212212,0.0012412412412412413,0.0012612612612612612,0.0012812812812812813,0.0013013013013013013,0.0013213213213213212,0.0013413413413413413,0.0013613613613613614,0.0013813813813813814,0.0014014014014014013,0.0014214214214214214,0.0014414414414414415,0.0014614614614614613,0.0014814814814814814,0.0015015015015015015,0.0015215215215215216,0.0015415415415415414,0.0015615615615615615,0.0015815815815815816,0.0016016016016016017,0.0016216216216216215,0.0016416416416416416,0.0016616616616616617,0.0016816816816816816,0.0017017017017017016,0.0017217217217217217,0.0017417417417417418,0.0017617617617617617,0.0017817817817817817,0.0018018018018018018,0.0018218218218218217,0.0018418418418418418,0.0018618618618618619, ...

# %%
Dt = 50.0e-6
t = 4.0*Dt
t_1 = t
t_2 = t + Dt

c_1 =   np.arcsin(np.sin(2.0*np.pi*2500*t_1))/(np.pi/2.0)
c_2 =   np.arcsin(np.sin(2.0*np.pi*2500*t_2))/(np.pi/2.0)

u = np.zeros((7,1))
u[0] = -0.49
u[1] = 0
u[2] = 0
        
t_s = (t_2-t_1)/(c_2 - c_1)*(u[0,0] - c_1) + t_1

if u[0,0]>c_1 and u[0,0]<c_2:
    eta = -((t_s - t_1)*(-1.0) + (t_2-t_s)*( 1.0))/Dt

if u[0,0]<c_1 and u[0,0]>c_2:
    eta = -((t_s - t_1)*( 1.0) + (t_2-t_s)*(-1.0))/Dt

if u[0,0]>c_1 and u[0,0]>c_2:
    eta = 1.0
    
if u[0,0]<c_1 and u[0,0]<c_2:
    eta = -1.0
    
print('t_s = {:2.3g} s'.format(t_s))
print('eta = {:2.3g}'.format(eta))

fig = figure(width=800, height=300)
fig.line(x=[t_1,t_2], y=[c_1,c_2], color="red")
fig.line(x=[t_1,t_2], y=[u[0],u[0]], color="blue")
show(fig)
# Out:
# t_s = 0.000249 s
# eta = -0.96
#     <div class="bk-root">
#         <div class="plotdiv" id="b342eb5a-40ab-426f-9ecc-5e665a6bbbf1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b342eb5a-40ab-426f-9ecc-5e665a6bbbf1").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b342eb5a-40ab-426f-9ecc-5e665a6bbbf1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b342eb5a-40ab-426f-9ecc-5e665a6bbbf1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"64ac9c8d-944b-41c9-80cc-65dcbac22bc4":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"476d2973-97ee-4996-8ebe-c7fb754b53ce","type":"Line"},{"attributes":{"plot":{"id":"3cbf7429-3492-4f5b-85b1-26e66c451617","subtype":"Figure","type":"Plot"}},"id":"028af84e-64dd-4bf9-bc22-b4e9adf15ab0","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"3cbf7429-3492-4f5b-85b1-26e66c451617","subtype":"Figure","type":"Plot"}},"id":"44df815c-5331-4041-9ef4-85cf3dabab02","type":"HelpTool"},{"attributes":{},"id":"6ac31aaf-1f24-46d1-bbe4-0ca765e06c81","type":"BasicTicker"},{"attributes":{"data_source":{"id":"5e9b9f35-1d46-462d-9588-6aff9f56c58c","type":"ColumnDataSource"},"glyph":{"id":"c7832c62-4e2b-41df-bb81-d6e83e059317","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"2a872a49-f607-4391-87cb-2a33f9a14392","type":"Line"},"selection_glyph":null},"id":"652f2ea5-409b-42e2-ae5e-5adf3d400b91","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"2bcecb01-045e-4b1e-bd45-a7bef5d44692","type":"BasicTickFormatter"},"plot":{"id":"3cbf7429-3492-4f5b-85b1-26e66c451617","subtype":"Figure","type":"Plot"},"ticker":{"id":"6ac31aaf-1f24-46d1-bbe4-0ca765e06c81","type":"BasicTicker"}},"id":"9a41593e-992b-4164-bebd-bd7eb655be9c","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4ab6d6a4-9452-4a73-9440-431e198695f8","type":"PanTool"},{"id":"028af84e-64dd-4bf9-bc22-b4e9adf15ab0","type":"WheelZoomTool"},{"id":"b9681ea6-dcb6-4285-b315-31b2f6b8a808","type":"BoxZoomTool"},{"id":"3efae05d-f742-457b-ae6e-3c06f9d46a1b","type":"SaveTool"},{"id":"89ffcbd1-bd2e-4570-8ac5-cd65ba3ed240","type":"ResetTool"},{"id":"44df815c-5331-4041-9ef4-85cf3dabab02","type":"HelpTool"}]},"id":"9f42f3e8-4da4-4096-8b84-49695362f73b","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a872a49-f607-4391-87cb-2a33f9a14392","type":"Line"},{"attributes":{},"id":"17e916fc-0839-4a1a-9cf7-e9058be5d7cf","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0002,0.00025],"y":[-2.0475253503525845e-16,-0.49999999999999994]}},"id":"c6821292-d65b-4276-978a-bf44c06505b8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0002,0.00025],"y":[[-0.49],[-0.49]]}},"id":"5e9b9f35-1d46-462d-9588-6aff9f56c58c","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"9a41593e-992b-4164-bebd-bd7eb655be9c","type":"LinearAxis"}],"left":[{"id":"c76a8b81-fd52-4e0d-b742-1ef80af3f7cb","type":"LinearAxis"}],"plot_height":300,"plot_width":800,"renderers":[{"id":"9a41593e-992b-4164-bebd-bd7eb655be9c","type":"LinearAxis"},{"id":"5e72207b-215f-46b1-a2f8-8817670863bd","type":"Grid"},{"id":"c76a8b81-fd52-4e0d-b742-1ef80af3f7cb","type":"LinearAxis"},{"id":"519452d8-2e4d-48f2-9f0c-cc5667ee4568","type":"Grid"},{"id":"0df50ffc-8998-4fed-8282-59a5df300e24","type":"BoxAnnotation"},{"id":"924f629b-4e83-4d8d-b155-7e8fd0207b2f","type":"GlyphRenderer"},{"id":"652f2ea5-409b-42e2-ae5e-5adf3d400b91","type":"GlyphRenderer"}],"title":{"id":"ce7a9e1f-3bc4-4677-a216-00cb8802d1c6","type":"Title"},"tool_events":{"id":"50da4375-6d95-4a11-b4a1-ee3ea0e35008","type":"ToolEvents"},"toolbar":{"id":"9f42f3e8-4da4-4096-8b84-49695362f73b","type":"Toolbar"},"x_range":{"id":"bdd62db2-8a17-4ee7-93a0-9985d834c812","type":"DataRange1d"},"y_range":{"id":"1da06167-588c-4dfc-8b2b-9576a6250fe3","type":"DataRange1d"}},"id":"3cbf7429-3492-4f5b-85b1-26e66c451617","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"3cbf7429-3492-4f5b-85b1-26e66c451617","subtype":"Figure","type":"Plot"}},"id":"89ffcbd1-bd2e-4570-8ac5-cd65ba3ed240","type":"ResetTool"},{"attributes":{"data_source":{"id":"c6821292-d65b-4276-978a-bf44c06505b8","type":"ColumnDataSource"},"glyph":{"id":"edcb6c22-e7ae-4ff5-b135-2528928 ...

# %%
t_s
# Out:
# 0.00024899999999999998

# %%
eta
# Out:
# -0.95999999999999885
