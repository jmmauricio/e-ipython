# %%
import numpy as np
import scipy.signal as sps
import sympy as sym 
import scipy.optimize as sopt
from scipy.integrate import ode
# %matplotlib inline   
import matplotlib.pyplot as plt
from sympy.utilities.lambdify import lambdify

# %%
VD = np.array([-1000, 0.0, 0.7,  2.0])
ID = np.array([ -5.0, 0.0, 1.0, 1000])

fig = plt.figure(figsize=(10,8))

ax1    = fig.add_subplot(1,1,1)
ax1.plot(VD,ID)

ax1.set_xlim((-5,5))
plt.show()

# %%
R_dc = 100.0
C = 1000e-6
R = 0.1
L = 1e-3



def fun(t,x,params):
    
    i_l = x[0]
    v_dc = x[1]
    
    omega = 2*np.pi*50.0
    
    v = 325*np.sin(omega*t)
    
    v_d = np.interp(i_l, ID, VD)
    
    
    di_l = 1.0/L*(v - R*i_l - v_d - v_dc)
    dv_dc = 1.0/C*(i_l - v_dc/R_dc)

        
    return [di_l, dv_dc]
    

x_0 = np.array([0.0,0.0])
r = ode(fun).set_integrator('dopri5')
r.set_initial_value(x_0,0.0).set_f_params(-20e3)
t1 = 1.0
dt = 0.001

T = [0.0]
X = [x_0]

while r.successful() and r.t < t1:
    if r.t>0.5:
        r.set_f_params(-150e3)

    T += [r.t+dt]
    X += [r.integrate(r.t+dt)]

    
T = np.array(T)
X = np.array(X)

fig = plt.figure(figsize=(10,8))

ax1    = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

ax1.plot(T,X[:,0])
ax2.plot(T,X[:,1])

plt.show()

# %%
def i_d_eval(v_d):
    V_t = 0.1
    n = 1.5
    I_s = 0.0001
    
    I = I_s*(np.exp(v_d/(n*V_t))-1)
    
    return I

def v_d_eval(i_d):
    V_t = 0.1
    n = 1.5
    I_s = 0.0001
    
    v_d = np.log2(i_d/I_s+1)*(n*V_t) 
    
    return v_d



fig = plt.figure(figsize=(10,8))

VD = np.linspace(-100,2,10)
ID = i_d_eval(v_d)


ax1    = fig.add_subplot(2,1,1)

VD = np.linspace(-100,2,10)
ID = v_d_eval(VD)

ax2 = fig.add_subplot(2,1,2)

ax2.plot(VD,ID)

plt.show()
# Out:
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:15: RuntimeWarning: invalid value encountered in log2

# %%
np.log2(-2)
# Out:
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in log2
#   if __name__ == '__main__':
# nan

# %%
R_dc = 10.0
C = 1000e-6
R = 0.1
L = 1e-3

VD = np.array([-1000, 0.0, 0.7,  2.0])
ID = np.array([ -5.0, 0.0, 1.0, 1000])

def sigmoid(z):
    s = 1.0 / (1.0 + np.exp(-5.0 * z))
    return s

def fun(t,x,params):
    
    i_a = x[0]
    i_b = x[1]
    i_c = x[2]
    v_dc = x[3]
    
    omega = 2*np.pi*50.0
    
    v_s_a = 325*np.sin(omega*t)
    v_s_b = 325*np.sin(omega*t - 2.0/3.0*np.pi)
    v_s_c = 325*np.sin(omega*t - 4.0/3.0*np.pi)
    
    u_a = 0.0
    u_b = 0.0
    u_c = 0.0
        
    if i_a>=0.0: u_a = 1.0
    if i_b>=0.0: u_b = 1.0
    if i_c>=0.0: u_c = 1.0
            
    u_a = sigmoid(i_a)
    u_b = sigmoid(i_b)
    u_c = sigmoid(i_c)
    
    
    
    e_a = (2*u_a - u_b - u_c)/3.0*v_dc
    e_b = (2*u_b - u_c - u_a)/3.0*v_dc
    e_c = (2*u_c - u_a - u_b)/3.0*v_dc
    
    di_a = 1.0/L*(v_s_a - R*i_a - e_a)
    di_b = 1.0/L*(v_s_b - R*i_b - e_b)
    di_c = 1.0/L*(v_s_c - R*i_c - e_c)
    
    i_d = u_a*i_a + u_b*i_b + u_c*i_c
    
    dv_dc = 1.0/C*(i_d - v_dc/R_dc)

        
    return [di_a, di_b,di_c,dv_dc]
    

x_0 = np.array([0.0,0.0,0.0,0.0])
r = ode(fun).set_integrator('dopri5')
r.set_initial_value(x_0,0.0).set_f_params(-20e3)
t1 = 0.1
dt = 0.0001

T = [0.0]
X = [x_0]

while r.successful() and r.t < t1:
    if r.t>0.5:
        r.set_f_params(-150e3)

    T += [r.t+dt]
    X += [r.integrate(r.t+dt)]

    
T = np.array(T)
X = np.array(X)

fig = plt.figure(figsize=(10,8))

ax1    = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

ax1.plot(T,X[:,0:3])
ax2.plot(T,X[:,3])

plt.show()
# Out:
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:10: RuntimeWarning: overflow encountered in exp

# %%
import numpy as np
import scipy.signal as sps
import sympy as sym 
import scipy.optimize as sopt
from scipy.integrate import ode
# %matplotlib inline   
import matplotlib.pyplot as plt
from sympy.utilities.lambdify import lambdify
import time as time

# %%
u_a,u_b,u_c = sym.symbols('u_a,u_b,u_c')
i_a,i_b,i_c,v_dc = sym.symbols('i_a,i_b,i_c,v_dc')
L,R,C,R_dc,omega,t,sigmoid_param = sym.symbols('L,R,C,R_dc,omega,t,sigmoid_param')

# %%
v_s_a = 325*sym.sin(omega*t)
v_s_b = 325*sym.sin(omega*t - 2.0/3.0*np.pi)
v_s_c = 325*sym.sin(omega*t - 4.0/3.0*np.pi)
    
u_a = 1.0 / (1.0 + sym.exp(-sigmoid_param * (i_a)))
u_b = 1.0 / (1.0 + sym.exp(-sigmoid_param * (i_b)))
u_c = 1.0 / (1.0 + sym.exp(-sigmoid_param * (i_c)))
       
e_a = (2*u_a - u_b - u_c)/3.0*v_dc
e_b = (2*u_b - u_c - u_a)/3.0*v_dc
e_c = (2*u_c - u_a - u_b)/3.0*v_dc
    
di_a = 1.0/L*(v_s_a - R*i_a - e_a)
di_b = 1.0/L*(v_s_b - R*i_b - e_b)
di_c = 1.0/L*(v_s_c - R*i_c - e_c)
    
i_d = u_a*i_a + u_b*i_b + u_c*i_c
    
dv_dc = 1.0/C*(i_d - v_dc/R_dc)

f = sym.Matrix([[di_a],[di_b],[di_c],[dv_dc]])
x = sym.Matrix([[i_a],[i_b],[i_c],[v_dc]])

F_x = f.jacobian(x)

# %%
params = {'L':10e-3,
          'R':0.1,
          'C':2000.0e-6,
          'omega':2.0*np.pi*50,
          'R_dc':10,
          'sigmoid_param':5.0
         }

u_sym = sym.Matrix([[i_a],[i_b],[i_c],[v_dc]])

f_sym = lambdify((t,u_sym,R_dc), f.subs(params),'numpy') # returns a numpy-ready function
jac = lambdify((t,u_sym,R_dc), F_x.subs(params),'numpy') # returns a numpy-ready function

# %%
x_0 = np.array([0.0,0.0,0.0,400.0])
r = ode(f_sym,jac).set_integrator('dop853', method='adams')
r.set_initial_value(x_0,0.0).set_f_params(10).set_jac_params(10.0)
t1 = 2.0
dt = 0.0001

T = [0.0]
X = [x_0]

t_0 = time.time()
while r.successful() and r.t < t1:
    if r.t>0.5:
        r.set_f_params(10).set_jac_params(10.0)

    T += [r.t+dt]
    X += [r.integrate(r.t+dt)]

print(time.time() - t_0)
    
T = np.array(T).real
X = np.array(X).real

fig = plt.figure(figsize=(10,8))

ax1    = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

ax1.plot(T,X[:,0:3])
ax2.plot(T,X[:,3])

plt.show()
# Out:
# 20.452988386154175

# %%
params = {'L':1e-3,
          'R':0.1,
          'C':2000.0e-6,
          'omega':2.0*np.pi*50,
          'sigmoid_param':1000.0
         }

u_sym = sym.Matrix([[i_a],[i_b],[i_c],[v_dc]])

f_sym = lambdify((t,u_sym,R_dc), f.subs(params),'numpy') # returns a numpy-ready function
jac = lambdify((t,u_sym,R_dc), F_x.subs(params),'numpy') # returns a numpy-ready function


x_0 = np.array([0.0,0.0,0.0,400.0])
t1 = 0.2
dt = 1e-6

T = [0.0]
X = [x_0]
x_i = x_0
t_0 = time.time()
t_i = 0.0

R_dc_val = 100.0 
while t_i < t1:
             
    t_i += dt
    T += [t_i]
    
    if t_i>0.1: R_dc_val = 1.0e3
    
    x_i = x_i + dt*f_sym(t_i,x_i,R_dc_val).reshape(4)
             
    X += [x_i]

print(time.time() - t_0)
    
T = np.array(T).real
X = np.array(X).real

fig = plt.figure(figsize=(10,8))

ax1    = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

ax1.plot(T,X[:,0:3])
ax2.plot(T,X[:,3])

plt.show()
# Out:
# /home/jmmauricio/bin/anaconda3/lib/python3.5/site-packages/numpy/__init__.py:1: RuntimeWarning: overflow encountered in exp
#   """
# 14.144705057144165

# %%
f_sym(t,x_0,10.0).reshape(4)
# Out:
# array([  20406.91884703, -291106.32207781,  270699.40323078,  -20000.        ])

# %%
import numba 
from numba import float64
import numpy as np
import matplotlib.pyplot as plt
import diode
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import gridplot
output_notebook()

R_dc = 1000.0
C = 2000e-6
R = 1.0
L = 1e-3
omega = 2.0*np.pi*50.0
t = 0.0
sigmoid_param = 2500

VD = np.array([-1000, 0.0, 0.7,  2.0])
ID = np.array([ -5.0, 0.0, 1.0, 1000])

from numba import jit

#@numba.jit(float64[:](float64,float64,float64[:],float64,float64[:]))
@numba.jit
def f_diode(t,u,x,y,param):
    
    i_a = x[0]
    i_b = x[1]
    i_c = x[2]
    v_dc = x[3]
    
    R_dc = param[0]
    V_ac = param[1]
    omega = param[3]
    L = param[4]
    R = param[5]
    
    v_s_a = V_ac*np.sin(omega*t)
    v_s_b = V_ac*np.sin(omega*t - 2.0/3.0*np.pi)
    v_s_c = V_ac*np.sin(omega*t - 4.0/3.0*np.pi)
    
    u_a = 0.0
    if i_a >= 0.0: u_a = 1.0       
    
    u_b = 0.0
    if i_b >= 0.0: u_b = 1.0 
     
    u_c = 0.0
    if i_c >= 0.0: u_c = 1.0 
                   
    e_a = (2*u_a - u_b - u_c)/3.0*v_dc
    e_b = (2*u_b - u_c - u_a)/3.0*v_dc
    e_c = (2*u_c - u_a - u_b)/3.0*v_dc

    di_a = 1.0/L*(v_s_a - R*i_a - e_a)
    di_b = 1.0/L*(v_s_b - R*i_b - e_b)
    di_c = 1.0/L*(v_s_c - R*i_c - e_c)

    i_d = u_a*i_a + u_b*i_b + u_c*i_c

    dv_dc = 1.0/C*(i_d - (v_dc)/R_dc)

    return np.array([di_a, di_b,di_c,dv_dc])

@numba.jit
def run():
    dt = 2e-6
    t_end = 0.1   
    decimation = 10
    T = np.zeros((int(t_end/dt/decimation),1))
    X = np.zeros((int(t_end/dt/decimation),4))
    
    t = 0.0
    x_0 = np.array([0.0,0.0,0.0,400.0])
    x = x_0

    X[0,:] = x
    
    param = np.array([10,  # R_dc
                      325.0, # V_ac
                      2.0*np.pi*50.0,
                      L,
                      R,
                      C
                     ])


    
    it = 0
    it_decimation = 0
    it_save = 0
    solver = 'fweuler'
    while t < t_end:   
        if t > 1.0:
            param[0] = 10.0
            
        t += dt        

        if solver == 'fweuler':
            # solver trapezoidal 1 step
            x = x + dt*(diode.f_diode(t,0.0,x,0.0,param))
        
        if solver == 'trapezoidal':
            # solver trapezoidal 1 step
            f_1 = diode.f_diode(t,0.0,x,0.0,param)
            x_1 = x + dt*f_1
            x = x + 0.5*dt*(diode.f_diode(t,0.0,x_1,0.0,param) + f_1)

        it += 1
        
        if it_decimation >= decimation:
            it_save += 1  
            X[it_save,:] = x
            T[it_save,:] = t
            it_decimation = 0
            
        it_decimation += 1
              
        
        
    return T,X

param={'dt': 2e-6, 't_end': 0.1, 'decimation': 10}

param_diodes = {'param_diodes': np.array( [10,  # R_dc
                          325.0, # V_ac
                          2.0*np.pi*50.0,
                          L,
                          R,
                          C
                         ])
    
param.update(param_diodes)
        
# %timeit run(param)

T,X = run(param)

fig1 = figure(width=800, height=300)
fig1.line(x=T[:,0], y=X[:,0], color="red")
fig1.line(x=T[:,0], y=X[:,1], color="green")
fig1.line(x=T[:,0], y=X[:,2], color="blue")
 
fig2 = figure(width=800, height=300,  x_range=fig1.x_range,)
fig2.line(x=T[:,0], y=X[:,3], color="magenta")

figs = gridplot([[fig1], [fig2]])

show(figs)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b922683a-1b5e-4f94-81b6-3081c7273635">Loading BokehJS ...</span>
#     </div>
# The slowest run took 5.00 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1 loop, best of 3: 266 ms per loop
#     <div class="bk-root">
#         <div class="plotdiv" id="12f0f7bd-0ada-4931-838a-ead928ebff44"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#12f0f7bd-0ada-4931-838a-ead928ebff44").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("12f0f7bd-0ada-4931-838a-ead928ebff44");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '12f0f7bd-0ada-4931-838a-ead928ebff44' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ddf3fb69-0124-4d72-9cf4-51a10f6ba597":{"roots":{"references":[{"attributes":{},"id":"be72c4ec-4c31-4a17-812a-53e384acff96","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5fbd02ec-c732-43cb-a59b-0076652b88a5","type":"Line"},{"attributes":{"children":[{"id":"29fb498c-ad12-48ae-a39e-fb5558cb0c65","type":"ToolbarBox"},{"id":"63db6fe1-bda0-44ea-950f-402ca2dacf9b","type":"Column"}]},"id":"2a2d23f7-db28-4432-9b67-982cafbefa5b","type":"Column"},{"attributes":{"plot":{"id":"bac457b8-e163-4524-a98b-0628b12fbe1e","subtype":"Figure","type":"Plot"}},"id":"d4372251-03ed-409b-b7e2-2ee889a2576c","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"87f96346-68b5-4ce6-93a1-f2ca78bab1ca","type":"BoxAnnotation"},"plot":{"id":"634b9e7d-b857-4e2a-b1b9-81e0f7ceb255","subtype":"Figure","type":"Plot"}},"id":"b9a2efd4-12fd-4eb5-9d7f-5d60ced510d3","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"97c1f8f8-94c0-40d5-9f17-d07f62e2ce42","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"52178f0c-b032-48e5-a329-025c74a18b37","type":"BasicTickFormatter"},"plot":{"id":"634b9e7d-b857-4e2a-b1b9-81e0f7ceb255","subtype":"Figure","type":"Plot"},"ticker":{"id":"87561872-c8fe-415c-8719-8a6fb43c38cc","type":"BasicTicker"}},"id":"ff8b5c77-f87b-4829-92ec-43346203e379","type":"LinearAxis"},{"attributes":{"plot":{"id":"634b9e7d-b857-4e2a-b1b9-81e0f7ceb255","subtype":"Figure","type":"Plot"}},"id":"fb231a57-99af-4725-9628-ce43369a068c","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"3634ef11-5bb1-4482-9d36-6d60b15845fe","type":"DataRange1d"},{"attributes":{"children":[{"id":"46534443-4c8c-4958-b89a-03703b70e424","type":"Row"},{"id":"9f9d91a6-de9e-4c53-9dcd-b49daff58faa","type":"Row"}]},"id":"63db6fe1-bda0-44ea-950f-402ca2dacf9b","type":"Column"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"534256d5-e727-40e4-bdf3-364c3a69fd20","type":"Line"},{"attributes":{"plot":{"id":"634b9e7d-b857-4e2a-b1b9-81e0f7ceb255","subtype":"Figure","type":"Plot"}},"id":"2fdf0f1f-810a-460d-bbfb-9fef36e6dc85","type":"SaveTool"},{"attributes":{"data_source":{"id":"afbe94a9-8915-42f4-9044-c5a87e34c825","type":"ColumnDataSource"},"glyph":{"id":"45ae1377-a1b5-468b-ae6d-4f24454ecd18","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"b47c641f-3d7c-4983-b1f1-ae3936c57cad","type":"Line"},"selection_glyph":null},"id":"88b900d2-6c05-4f3b-87a8-39b78a08e94b","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"ae11778d-d0ed-4135-be3c-990c158bbd84","type":"Title"},{"attributes":{"callback":null},"id":"fe742f38-943a-4c7b-b17d-5d78530f3bea","type":"DataRange1d"},{"attributes":{},"id":"52178f0c-b032-48e5-a329-025c74a18b37","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":null},"id":"f93e508d-06c7-4dea-8ff7-c1138176cf87","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"634b9e7d-b857-4e2a-b1b9-81e0f7ceb255","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb774833-01de-41f4-8d2c-1c7b67c7f7a7","type":"BasicTicker"}},"id":"3ca95254-690e-45b5-9193-b038a05a0992","type":"Grid"},{"attributes":{"callback":null},"id":"bb683190-9ad6-4a6d-8918-4b18394f4a74","type":"DataRange1d"},{"attributes":{},"id":"6d6a8da1-98f4-402c-b50c-6b9d6871ca24","type":"ToolEvents"},{"attributes":{"plot":{"id":"bac457b8-e163-4524-a98b-0628b12fbe1e","subtype":"Figure","type":"Plot"}},"id":"32213135-b08d-4a30-8197-f63aff89e74c","type":"PanTool"},{"attributes":{},"id":"72d2b994-95d7-4533-a233-243f94cd90ab","type":"BasicTickFormatter"},{"attributes":{},"id":"eb774833-01de-41f4-8d2c-1c7b67c7f7a ...

# %%
T
# Out:
# array([[  0.00000000e+00],
#        [  2.20000000e-05],
#        [  4.20000000e-05],
#        ...,
#        [  9.99420000e-02],
#        [  9.99620000e-02],
#        [  9.99820000e-02]])

# %%
X.shape
# Out:
# (2000000, 4)

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8df5ea1e-0937-4094-adc0-affd78af3004">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure(width=300, height=300)
plot.inverted_triangle(x=[1, 2, 3], y=[1, 2, 3], size=20, color="#DE2D26")

show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9d61b9ba-96ab-4d3b-9ed5-7dcb68867a55"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9d61b9ba-96ab-4d3b-9ed5-7dcb68867a55").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9d61b9ba-96ab-4d3b-9ed5-7dcb68867a55");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9d61b9ba-96ab-4d3b-9ed5-7dcb68867a55' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8253208c-1568-41cd-9b8a-30753c007fc0":{"roots":{"references":[{"attributes":{"formatter":{"id":"e508cea9-e85d-4c77-b2e2-8cc11f6abcf9","type":"BasicTickFormatter"},"plot":{"id":"ea47c9dc-6b1d-4d89-9b35-ab1dcbe5a4a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"1b818192-cdbc-4589-8a99-10259b6a4cf0","type":"BasicTicker"}},"id":"f62fcf64-f8ad-48d6-bf2d-997f859290b6","type":"LinearAxis"},{"attributes":{"overlay":{"id":"803af516-73cc-43a6-9c3c-3f970bea205e","type":"BoxAnnotation"},"plot":{"id":"ea47c9dc-6b1d-4d89-9b35-ab1dcbe5a4a8","subtype":"Figure","type":"Plot"}},"id":"0dc5c8df-2cc8-4e18-a05a-36ad296c4130","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3],"y":[1,2,3]}},"id":"f6974f7e-40ba-490b-b282-41986795af1e","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ea47c9dc-6b1d-4d89-9b35-ab1dcbe5a4a8","subtype":"Figure","type":"Plot"}},"id":"7132f7ab-1384-43ad-979f-68fee9ef186c","type":"HelpTool"},{"attributes":{"data_source":{"id":"f6974f7e-40ba-490b-b282-41986795af1e","type":"ColumnDataSource"},"glyph":{"id":"cbe36c41-9651-4bfa-8e5a-96b1bce3fe1b","type":"InvertedTriangle"},"hover_glyph":null,"nonselection_glyph":{"id":"6486baa3-05a5-4757-98a8-f43e0984f644","type":"InvertedTriangle"},"selection_glyph":null},"id":"26f405a1-9312-4511-a9c3-e1ceb147956f","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#DE2D26"},"line_color":{"value":"#DE2D26"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"cbe36c41-9651-4bfa-8e5a-96b1bce3fe1b","type":"InvertedTriangle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"803af516-73cc-43a6-9c3c-3f970bea205e","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"ea47c9dc-6b1d-4d89-9b35-ab1dcbe5a4a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"9fab5691-9612-4b54-af30-0c9e41ff54f1","type":"BasicTicker"}},"id":"0130fae7-6e38-448f-8a19-5e4d4483d36d","type":"Grid"},{"attributes":{"callback":null},"id":"bb9cbaec-e9e7-4c93-a5b2-4d82964f8fce","type":"DataRange1d"},{"attributes":{"callback":null},"id":"6479f1ca-b12c-46da-ab05-5b6b8ed41ae7","type":"DataRange1d"},{"attributes":{"plot":{"id":"ea47c9dc-6b1d-4d89-9b35-ab1dcbe5a4a8","subtype":"Figure","type":"Plot"}},"id":"13aea96d-958d-4f99-ae16-0d042a1188d2","type":"SaveTool"},{"attributes":{"plot":null,"text":null},"id":"ddbaecf5-16b8-4df0-9b55-93f38e63b088","type":"Title"},{"attributes":{},"id":"e508cea9-e85d-4c77-b2e2-8cc11f6abcf9","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"ea47c9dc-6b1d-4d89-9b35-ab1dcbe5a4a8","subtype":"Figure","type":"Plot"}},"id":"cb15901b-7638-404c-8664-7c0d06196962","type":"ResetTool"},{"attributes":{"plot":{"id":"ea47c9dc-6b1d-4d89-9b35-ab1dcbe5a4a8","subtype":"Figure","type":"Plot"}},"id":"b6c13985-247e-4edd-a2b6-92b614f9bfd6","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b6c13985-247e-4edd-a2b6-92b614f9bfd6","type":"PanTool"},{"id":"02032cab-265b-4f65-be36-404df0d83568","type":"WheelZoomTool"},{"id":"0dc5c8df-2cc8-4e18-a05a-36ad296c4130","type":"BoxZoomTool"},{"id":"13aea96d-958d-4f99-ae16-0d042a1188d2","type":"SaveTool"},{"id":"cb15901b-7638-404c-8664-7c0d06196962","type":"ResetTool"},{"id":"7132f7ab-1384-43ad-979f-68fee9ef186c","type":"HelpTool"}]},"id":"fd28fa0e-f17b-43d4-9769-e590886868ad","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"6486baa3-05a5-4757-98a8-f43e0984f644","type":"InvertedTriangle"},{"attributes":{"plot":{"id":"ea47c9dc-6b1d-4d89-9b35 ...
