# %%
import numpy as np
from IPython.display import Image

# %%
Image("figura_p3_enunciado.png")

# %%
P_n = 15.0e3
cos_phi = 0.87
rend = 0.885
U = 400.0
I_arr_I_n = 7.3

L = 20.0

# %%
P_1 = P_n/rend
I_1 = P_1/(np.sqrt(3.0)*U*cos_phi)

# %%
I_1
# Out:
# 28.119533858836245

# %%
I_b = 1.25*I_1

# %% [markdown]
# ### Criterio térmico

# %%
Image("../seccion_termica/ict_bt_07_tubo.png")

# %%
F_tubo = 0.8 # por estar en tubo

# %%
I_Z = I_b
I_Z0 = I_Z/(F_tubo)

# %%
I_Z0
# Out:
# 43.936771654431631

# %%
Image("../seccion_termica/ict_bt_07_tbl_5.png")

# %%
S = 6.0 # mm2 -> I_Z0 = 72 A (unipolares, XLPE)

# %% [markdown]
# ### Caída de tensión

# %%
Image("figura_p2_Du.png")

# %%
Du_cosphi_100 = 6.74
Du_cosphi_80  = 5.51

# Du = sqrt(3)*(R*cosphi+X*sinphi)

# %%
R = Du_cosphi_100/(np.sqrt(3))
X = (Du_cosphi_80/(np.sqrt(3))-R*0.8)/0.6

# %%
X
# Out:
# 0.11354555294062596

# %%
Du_cosphi_87  = np.sqrt(3.0)*(R*0.87+X*np.sin(np.arccos(0.87)))

# %%
DU = L/1000.0*I_b*Du_cosphi_87

# %%
DU<(0.05*400)
# Out:
# True
