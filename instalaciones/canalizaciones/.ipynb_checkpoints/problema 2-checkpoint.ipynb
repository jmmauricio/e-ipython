# %%
import numpy as np
from IPython.display import Image

# %%
Image("figura_p2_enunciado.png")

# %%
L_OA = 40.0e-3
L_AB = 30.0e-3
L_AC = 20.0e-3

I_A_m = 9.0e3/(np.sqrt(3.0)*400.0)
I_B_m = 5.0e3/(np.sqrt(3.0)*400.0)
I_C_m = 9.0e3/(np.sqrt(3.0)*400.0)

# %%
I_AB_m = I_B_m
I_AC_m = I_C_m
I_OA_m = I_AB_m + I_AC_m + I_A_m

# %%
Image("figura_p2_Du.png")

# %%
U_OA_m = L_OA*I_OA_m*1.38  # Du para cos(phi) = 0.8, 25 mm2
U_AB_m = L_AB*I_AB_m*1.38
U_AC_m = L_AC*I_AC_m*1.38

U_OB_m = U_OA_m + U_AB_m
U_OC_m = U_OA_m + U_AC_m

# %%
print('U_AB_m<0.05*400 =',U_AB_m<0.05*400)
print('U_AC_m<0.05*400 =',U_AC_m<0.05*400)
# Out:
# U_AB_m<0.05*400 = True
# U_AC_m<0.05*400 = True

# %% [markdown]
# ### Criterio térmico

# %%
Image("../seccion_termica/ict_bt_07_tbl_6.png")

# %%
F_temp_terreno = 1.07 # temperatura de terreno = 15ºC

# %%
Image("../seccion_termica/ict_bt_07_tubo.png")

# %%
F_tubo = 0.8 # por estar en tubo

# %%
I_Z = I_OA_m
I_Z0 = I_Z/(F_temp_terreno*F_tubo)

# %%
I_Z0
# Out:
# 38.782290278508739

# %%
Image("../seccion_termica/ict_bt_07_tbl_5.png")

# %%
S = 25.0 # mm2 -> I_Z0 = 150 A (tetrapolar, XLPE)
