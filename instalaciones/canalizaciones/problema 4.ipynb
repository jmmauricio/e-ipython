# %%
import numpy as np
from IPython.display import Image

# %%
Image("figura_p4_enunciado.png")

# %% [markdown]
# ### Criterio térmico

# %%
Image("../seccion_termica/ict_bt_07_tbl_13.png")

# %%
F_tubo = 0.8 # por estar en tubo
F_t_a = 0.9 # por estar a 50C

# %%
I_Z = I_b
I_Z0 = I_Z/(F_tubo)

# %%
I_Z0
# Out:
# 43.936771654431631

# %%
Image("../seccion_termica/ict_bt_07_tbl_12.png")

# %%
S = 6.0 # mm2 -> I_Z0 = 72 A (unipolares, XLPE)

# %% [markdown]
# ### Caída de tensión

# %%
Image("figura_p2_Du.png")

# %%
Du_cosphi_100 = 6.74
Du_cosphi_80  = 5.51

# Du = sqrt(3)*(R*cosphi+X*sinphi)

# %%
R = Du_cosphi_100/(np.sqrt(3))
X = (Du_cosphi_80/(np.sqrt(3))-R*0.8)/0.6

# %%
X
# Out:
# 0.11354555294062596

# %%
Du_cosphi_87  = np.sqrt(3.0)*(R*0.87+X*np.sin(np.arccos(0.87)))

# %%
DU = L/1000.0*I_b*Du_cosphi_87

# %%
DU<(0.05*400)
# Out:
# True
